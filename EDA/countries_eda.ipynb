# %%
#retriving from table
from sqlalchemy import create_engine
import pandas as pd

db_engine = create_engine("postgresql+psycopg2://postgres:123456@localhost:5432/global_debt_intelligence_hub")

all_countries = pd.read_sql("SELECT * FROM countries", db_engine)

# %%
len(all_countries)
# Out:
# 120

# %%
all_countries['region'].unique()
# Out:
# <StringArray>
# ['Middle East & North Africa',      'Europe & Central Asia',
#          'Sub-Saharan Africa',  'Latin America & Caribbean',
#                  'South Asia',        'East Asia & Pacific']
# Length: 6, dtype: str

# %%
all_countries.groupby('region')['country_code'].count().reset_index()
# Out:
#                        region  country_code
# 0         East Asia & Pacific            16
# 1       Europe & Central Asia            18
# 2   Latin America & Caribbean            22
# 3  Middle East & North Africa            13
# 4                  South Asia             6
# 5          Sub-Saharan Africa            45
